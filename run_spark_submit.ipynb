# %%
import findspark
findspark.init('/PythonApp/cloudera/parcels/CDH/lib/spark')

import os
#os.environ['JAVA_HOME'] = "/usr/java/jdk1.8.0_151-cloudera" #JAVA PATH
#os.environ['PYSPARK_PYTHON'] = "/opt/anaconda3/bin/python" #PYTHON PATH

from pyspark import SparkContext, SparkConf 
from pyspark.sql import HiveContext, SQLContext
conf = SparkConf()
conf.set('spark.yarn.appMasterEnv.SPARK_HOME','/PythonApp/cloudera/parcels/CDH/lib/spark2')
conf.set('spark.yarn.executor.memoryOverhead' , '16300')
conf.set('spark.executor.memory', '6g')
conf.set('spark.executor.cores', '5')
conf.set('spark.executor.instances', '15') 
conf.set('spark.dynamicAllocation.enabled','true')
#conf.set("spark.sql.execution.arrow.enabled", "true") #convert pandas df to spark df
sc = SparkContext(conf=conf)

sqlContext = SQLContext(sc) # create sqlcontext
hc = HiveContext(sc) # create hivecontext

#create df
hc.sql("show databases").show()
df=hc.sql('select * from staging_common.test_wb_sample limit 2')

df2=df.select('duns_nbr','oprg_stat_cd','utc_code')
df2.registerTempTable("test_wb")

df3 = hc.sql("select * from test_wb")
df3.show()
df3.write.mode('append').saveAsTable('staging_common.test_wb')

sc.stop()

#submit-mode
spark-submit \
--master yarn-cluster \
--conf "spark.yarn.appMasterEnv.SPARK_HOME=/opt/cloudera/parcels/CDH-5.12.2-1.cdh5.12.2.p0.4/lib/spark" \
--conf "spark.yarn.appMasterEnv.PYSPARK_PYTHON=/opt/anaconda3/bin/python" \
--conf "spark.yarn.appMasterEnv.PYSPARK_DRIVER_PYTHON=/opt/anaconda3/bin/python" \
Your_file_name.py

spark-submit \
--master yarn-cluster \
--conf "spark.yarn.appMasterEnv.SPARK_HOME=/opt/cloudera/parcels/CDH-5.12.2-1.cdh5.12.2.p0.4/lib/spark" \
--conf "spark.yarn.appMasterEnv.PYSPARK_PYTHON=/opt/anaconda3/bin/python" \
--conf "spark.yarn.appMasterEnv.PYSPARK_DRIVER_PYTHON=/opt/anaconda3/bin/python" \
--conf spark.dynamicAllocation.enabled=true \
--conf spark.executor.cores=4 \
--conf spark.executor.instances=15 \
--conf spark.executor.memory=10G  \
--conf spark.yarn.executor.memoryOverhead=11300  \
--conf spark.driver.memory=10G  \
--conf spark.yarn.driver.memoryOverhead=11300 \
--driver-java-options -XX:MaxPermSize=512M \
--driver-java-options -XX:PermSize=512M \
--files  /dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_4_562,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_3_496,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_2_634,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_1_442,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_0_559,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_0_773,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_3_856,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_4_983,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_1_991,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_2_976,/dnbusr1/chandraj/crating_encoder3.pkl \
pred_finalscoring_xgb_pyspark_noinq.py

spark-submit \
--master yarn-cluster \
--conf "spark.yarn.appMasterEnv.SPARK_HOME=/opt/cloudera/parcels/CDH-5.12.2-1.cdh5.12.2.p0.4/lib/spark" \
--conf "spark.yarn.appMasterEnv.PYSPARK_PYTHON=/opt/anaconda3/bin/python" \
--conf "spark.yarn.appMasterEnv.PYSPARK_DRIVER_PYTHON=/opt/anaconda3/bin/python" \
--conf spark.dynamicAllocation.enabled=true \
--conf spark.executor.cores=4 \
--conf spark.executor.instances=15 \
--conf spark.executor.memory=10G  \
--conf spark.yarn.executor.memoryOverhead=11300  \
--conf spark.driver.memory=10G  \
--conf spark.yarn.driver.memoryOverhead=11300 \
--driver-java-options -XX:MaxPermSize=512M \
--driver-java-options -XX:PermSize=512M \
--files  /dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_4_562,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_3_496,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_2_634,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_1_442,/dnbusr1/chandraj/pkl_bestM_inq12m_453_v3_5fold_june18_col0_prod_xgb_starter_fold_0_559,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_0_773,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_3_856,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_4_983,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_1_991,/dnbusr1/chandraj/pkl_bestM_noinq12m_453_v3_5fold_june18_col19fsic2_withhyper_logloss_prod-xgb_starter_fold_2_976,/dnbusr1/chandraj/crating_encoder3.pkl \
pred_finalscoring_xgb_pyspark_inq.py
